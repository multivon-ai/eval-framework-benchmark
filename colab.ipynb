# %% [markdown]
# # eval-framework-benchmark — one-click reproducer
#
# Reproduces the headline result: multivon-eval vs DeepEval vs RAGAS on the 100-case RAGTruth Summarization pilot (`ragtruth-sum`), judge gpt-4o-mini, single run — the same configuration as the README headline table.
#
# **Cost: roughly $0.10–$0.20 on OpenAI gpt-4o-mini for 100 cases × 3 frameworks × 1 run.**
#
# You'll need an OpenAI API key set via `OPENAI_API_KEY`.

# %% [markdown]
# ## 1. Clone + install

# %%
# !git clone https://github.com/multivon-ai/eval-framework-benchmark.git
# %cd eval-framework-benchmark
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 2. Set your OpenAI key

# %%
import os, getpass
os.environ['OPENAI_API_KEY'] = getpass.getpass('OpenAI API key: ')

# %% [markdown]
# ## 3. Load the deterministic 100-case RAGTruth Summary pilot subset
#
# The exact sample is committed as `data/ragtruth_sum_pilot_100.json`, so this is instant and offline.

# %%
# !python -m data.ragtruth_loader --n 100

# %% [markdown]
# ## 4. Run all three frameworks (single run, headline configuration)
#
# This is the main cost step (~$0.10–0.20). Results stream to `results/raw/gpt-4o-mini/` so you can interrupt and resume.

# %%
# !python run.py --task ragtruth-sum --n 100 --runs 1 --workers 6

# %% [markdown]
# ## 5. Analyze + write the report

# %%
# !python analyze.py --task ragtruth-sum --n 100

# %%
from IPython.display import Markdown
Markdown(open('results/RESULTS.md').read())

# %% [markdown]
# ## 6. Inspect a few raw judge outputs

# %%
import json, pathlib
rows = [json.loads(l) for l in pathlib.Path('results/raw/gpt-4o-mini/multivon-eval_ragtruth-sum_run0.jsonl').read_text().splitlines() if l.strip()]
for r in rows[:3]:
    print(r['case_id'], r['score'], r['flagged_hallucinated'], r['raw'])
